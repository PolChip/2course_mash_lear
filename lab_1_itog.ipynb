# %% [markdown]
# <a href="https://colab.research.google.com/github/PolChip/2course_mash_lear/blob/main/lab_1_itog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 18. Анализ и прогнозирование дорожных происшествий по историческим данным

# %%
import kagglehub
import pandas as pd

# Download latest version
path = kagglehub.dataset_download("himelsarder/road-accident-survival-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'road-accident-survival-dataset' dataset.
# Path to dataset files: /kaggle/input/road-accident-survival-dataset

# %%
df = pd.read_csv(path + '/accident.csv')
df.head()
# Out:
#    Age  Gender  Speed_of_Impact Helmet_Used Seatbelt_Used  Survived
# 0   56  Female             27.0          No            No         1
# 1   69  Female             46.0          No           Yes         1
# 2   46    Male             46.0         Yes           Yes         0
# 3   32    Male            117.0          No           Yes         0
# 4   60  Female             40.0         Yes           Yes         0

# %%
print(df.info())
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              200 non-null    int64
#  1   Gender           199 non-null    object
#  2   Speed_of_Impact  197 non-null    float64
#  3   Helmet_Used      200 non-null    object
#  4   Seatbelt_Used    200 non-null    object
#  5   Survived         200 non-null    int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 9.5+ KB
# None
#              Age  Speed_of_Impact   Survived
# count  200.00000       197.000000  200.00000
# mean    43.42500        70.441624    0.50500
# std     14.94191        30.125298    0.50123
# min     18.00000        20.000000    0.00000
# 25%     31.00000        43.000000    0.00000
# 50%     43.50000        71.000000    1.00000
# 75%     56.00000        95.000000    1.00000
# max     69.00000       119.000000    1.00000

# %% [markdown]
# Чтобы предсказывать погибнет человек или нет, мы будем использовать модель бинарной классификации
